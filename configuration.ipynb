# %%
configuration_para = {
    "organization": "your_organization",
    "projects": ["your_project_list"],
    "wiki_id": ["your_wiki_list"]
}
# Out:
# StatementMeta(, b972ab97-08af-4e96-ba60-3bf87ef0e6a5, 5, Finished, Available, Finished)

# %%
folder_path = "your_folder_path"
# Out:
# StatementMeta(, 108fbbf5-5786-4b6a-ae0e-1eec3c83938a, 4, Finished, Available, Finished)
