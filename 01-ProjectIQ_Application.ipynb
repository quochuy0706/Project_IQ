# %%
# %run "/00-Libraries"
# Out:
# StatementMeta(, 8aa9da04-c899-4139-bba9-b356d99018af, 87, Finished, Available, Finished)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
project_iq("What is the Uptime Score and Availability Score")
# Out:
# StatementMeta(, 8aa9da04-c899-4139-bba9-b356d99018af, 88, Finished, Available, Finished)
# 1. Uptime Score is the ratio of the elevators' operational time to the total possible operational time over a given period. This metric is used to measure the reliability and availability of elevator systems.2. The **Availability Score** in the context of elevator operation is a metric that measures the ratio of an elevator's operational time (when the elevator is functional and available for use) to the total possible operational time over a specific period. This score helps in assessing the performance and reliability of the elevator system by indicating how often the elevator is accessible for users compared to its total possible operable time.
